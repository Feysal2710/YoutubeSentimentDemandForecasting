# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from google.colab import files
import pandas as pd
import io #In all of the steps of step 7 I am checking the accuracy of all ML/DL models in Google collab

from google.colab import files
import pandas as pd
import io

print("📥 Please upload the English manually labelled file:")
uploaded_eng = files.upload()
english_filename = next(iter(uploaded_eng))
df_eng = pd.read_csv(io.BytesIO(uploaded_eng[english_filename]))

print("📥 Please upload the Dutch manually labelled file:")
uploaded_dutch = files.upload()
dutch_filename = next(iter(uploaded_dutch))
df_dutch = pd.read_csv(io.BytesIO(uploaded_dutch[dutch_filename]))


print("📥 Please upload the Combined dataset file:")
uploaded_comb = files.upload()
combined_filename = next(iter(uploaded_comb))
df_comb = pd.read_csv(io.BytesIO(uploaded_comb[combined_filename]))

# Clean datasets
df_eng = df_eng[df_eng["real_sentiment"].isin([-1, 0, 1])].dropna(subset=["Cleaned Comment Text"])
df_dutch = df_dutch[df_dutch["real_sentiment"].isin([-1, 0, 1])].dropna(subset=["Cleaned Comment Text"])
df_comb = df_comb[df_comb["real_sentiment"].isin([-1, 0, 1])].dropna(subset=["Cleaned Comment Text"])

# English
X_eng = df_eng["Cleaned Comment Text"].astype(str)
y_eng = df_eng["real_sentiment"]

# Dutch
X_dutch = df_dutch["Cleaned Comment Text"].astype(str)
y_dutch = df_dutch["real_sentiment"]

# Combined
X_comb = df_comb["Cleaned Comment Text"].astype(str)
y_comb = df_comb["real_sentiment"]

# Vectorizer
vectorizer = TfidfVectorizer(max_features=10000, ngram_range=(1, 2))

# Helper function
def run_lr(X, y, name=""):
    X_vec = vectorizer.fit_transform(X)
    X_train, X_val, y_train, y_val = train_test_split(X_vec, y, test_size=0.2, random_state=42, stratify=y)
    model = LogisticRegression(max_iter=1000, class_weight='balanced')
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    print(f"\n📊 Results for {name}")
    print("Accuracy:", accuracy_score(y_val, y_pred))
    print("Classification Report:\n", classification_report(y_val, y_pred, target_names=["Negative", "Neutral", "Positive"]))
    print("Confusion Matrix:\n", confusion_matrix(y_val, y_pred))

# Run for all three
run_lr(X_eng, y_eng, "English Manual Comments")
run_lr(X_dutch, y_dutch, "Dutch Manual Comments")
run_lr(X_comb, y_comb, "Combined Manual Comments")

# Clean datasets
df_eng = df_eng[df_eng["real_sentiment"].isin([-1, 0, 1])].dropna(subset=["Cleaned Comment Text"])
df_dutch = df_dutch[df_dutch["real_sentiment"].isin([-1, 0, 1])].dropna(subset=["Cleaned Comment Text"])
df_comb = df_comb[df_comb["real_sentiment"].isin([-1, 0, 1])].dropna(subset=["Cleaned Comment Text"])

# English
X_eng = df_eng["Cleaned Comment Text"].astype(str)
y_eng = df_eng["real_sentiment"]

# Dutch
X_dutch = df_dutch["Cleaned Comment Text"].astype(str)
y_dutch = df_dutch["real_sentiment"]

# Combined
X_comb = df_comb["Cleaned Comment Text"].astype(str)
y_comb = df_comb["real_sentiment"]

# Vectorizer
vectorizer = TfidfVectorizer(max_features=10000, ngram_range=(1, 2))

# Helper function
def run_lr(X, y, name=""):
    X_vec = vectorizer.fit_transform(X)
    X_train, X_val, y_train, y_val = train_test_split(X_vec, y, test_size=0.2, random_state=42, stratify=y)
    model = LogisticRegression(max_iter=1000, class_weight='balanced')
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    print(f"\n📊 Results for {name}")
    print("Accuracy:", accuracy_score(y_val, y_pred))
    print("Classification Report:\n", classification_report(y_val, y_pred, target_names=["Negative", "Neutral", "Positive"]))
    print("Confusion Matrix:\n", confusion_matrix(y_val, y_pred))

# Run for all three
run_lr(X_eng, y_eng, "English Manual Comments")
run_lr(X_dutch, y_dutch, "Dutch Manual Comments")
run_lr(X_comb, y_comb, "Combined Manual Comments")
# Out:
# 📥 Please upload the English manually labelled file:
#      <input type="file" id="files-40dee0b3-6358-49b6-88ec-eff150a227fd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-40dee0b3-6358-49b6-88ec-eff150a227fd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# Install imbalanced-learn
# !pip install -q imbalanced-learn

# Step 1: Imports
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from imblearn.over_sampling import SMOTE

# Step 2: Upload file
from google.colab import files
uploaded = files.upload()

import io
combined_filename = next(iter(uploaded_comb))
df_comb = pd.read_csv(io.BytesIO(uploaded_comb[combined_filename]))

# Step 3: Clean and prepare
df_comb = df_comb.dropna(subset=["Cleaned Comment Text"])
df_comb = df_comb[df_comb["real_sentiment"].isin([-1, 0, 1])]

X = df_comb["Cleaned Comment Text"]
y = df_comb["real_sentiment"]

# Step 4: Train-test split
X_train_texts, X_val_texts, y_train, y_val = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# Step 5: TF-IDF vectorization
vectorizer = TfidfVectorizer(max_features=10000)
X_train_vec = vectorizer.fit_transform(X_train_texts)
X_val_vec = vectorizer.transform(X_val_texts)

# Step 6: Apply SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_train_vec, y_train)

# Step 7: Train Logistic Regression
lr = LogisticRegression(max_iter=1000)
lr.fit(X_resampled, y_resampled)

# Step 8: Evaluate
y_pred = lr.predict(X_val_vec)

print("\n✅ Logistic Regression with SMOTE Results:\n")
print(classification_report(y_val, y_pred, target_names=["Negative", "Neutral", "Positive"]))
# Out:
#      <input type="file" id="files-a12e87ac-a058-45e3-b544-ebafe77ace54" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a12e87ac-a058-45e3-b544-ebafe77ace54">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
